# %% [markdown]
# This notebook compares the outputs from two static LAMMPS jobs one of which is an interactive job. Then outputs from the interactive and non-interactive jobs are checked for consistency.

# %%
from pyiron_atomistics import Project
import numpy as np
import pandas

# %%
pr = Project("water_interactive")
pr.remove_jobs_silently()
# Out:
# /tmp/ipykernel_577/1704746442.py:2: DeprecationWarning: pyiron_base.project.generic.remove_jobs_silently is deprecated: Use pr.remove_jobs(silently=True) rather than pr.remove_jobs_silently()..
#   pr.remove_jobs_silently()

# %%
dx = 0.7
cell = np.eye(3) * 10
r_O = [0, 0, 0]
r_H1 = [dx, dx, 0]
r_H2 = [-dx, dx, 0]
water = pr.create_atoms(elements=['H', 'H', 'O'],
                        positions=[r_H1, r_H2, r_O],
                        cell=cell, pbc=True)
# Out:
# /tmp/ipykernel_577/2925120900.py:6: DeprecationWarning: pyiron_atomistics.project.create_atoms is deprecated: Use create.structure.atoms instead.
#   water = pr.create_atoms(elements=['H', 'H', 'O'],

# %%
water_potential = pandas.DataFrame({    
    'Name': ['H2O_tip3p'],
    'Filename': [[]],
    'Model': ["TIP3P"],
    'Species': [['H', 'O']],
    'Config': [['# @potential_species H_O ### species in potential\n', '# W.L. Jorgensen et.al., The Journal of Chemical Physics 79, 926 (1983); https://doi.org/10.1063/1.445869\n', '#\n', '\n', 'units real\n', 'dimension 3\n', 'atom_style full\n', '\n', '# create groups ###\n', 'group O type 2\n', 'group H type 1\n', '\n', '## set charges - beside manually ###\n', 'set group O charge -0.830\n', 'set group H charge 0.415\n', '\n', '### TIP3P Potential Parameters ###\n', 'pair_style lj/cut/coul/long 10.0\n', 'pair_coeff * * 0.0 0.0 \n', 'pair_coeff 2 2 0.102 3.188 \n', 'bond_style harmonic\n', 'bond_coeff 1 450 0.9572\n', 'angle_style harmonic\n', 'angle_coeff 1 55 104.52\n', 'kspace_style pppm 1.0e-5\n', '\n']]
})

# %%
# Interactive job
job_int = pr.create.job.Lammps("test", delete_existing_job=True)
job_int.structure = water
job_int.potential = water_potential
job_int.interactive_open()
job_int.interactive_water_bonds = True
job_int.calc_static()
job_int.run()
job_int.interactive_close()
# Out:
# /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_atomistics/lammps/base.py:241: UserWarning: Non-'metal' units are not fully supported. Your calculation should run OK, but results may not be saved in pyiron units.
#   warnings.warn(
# The job test was saved and received the ID: 1
# [jupyter-jan-2djanssen-2ddeb-2dtegration-2dtests-2d6l5qyg29:00577] mca_base_component_repository_open: unable to open mca_btl_openib: librdmacm.so.1: cannot open shared object file: No such file or directory (ignored)
# /srv/conda/envs/notebook/lib/python3.10/site-packages/pylammpsmpi/wrapper/ase.py:165: UserWarning: Warning: setting upper trangular matrix might slow down the calculation
#   warnings.warn(

# %%
# Non-interactive job
job = pr.create.job.Lammps("test_ni", delete_existing_job=True)
job.structure = water
job.potential = water_potential
job.calc_static()
job.run()
# Out:
# /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_atomistics/lammps/base.py:241: UserWarning: Non-'metal' units are not fully supported. Your calculation should run OK, but results may not be saved in pyiron units.
#   warnings.warn(
# 2024-01-12 11:10:49,022 - pyiron_log - WARNING - Job aborted
# 2024-01-12 11:10:49,024 - pyiron_log - WARNING -
# The job test_ni was saved and received the ID: 2
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_base/jobs/job/runfunction.py:636, in execute_job_with_external_executable(job)
#     635 try:
# --> 636     out = subprocess.run(
#     637         executable,
#     638         cwd=job.project_hdf5.working_directory,
#     639         shell=shell,
#     640         stdout=subprocess.PIPE,
#     641         stderr=subprocess.STDOUT,
#     642         universal_newlines=True,
#     643         check=True,
#     644     ).stdout
#     645 except subprocess.CalledProcessError as e:
#
# File /srv/conda/envs/notebook/lib/python3.10/subprocess.py:526, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     525     if check and retcode:
# --> 526         raise CalledProcessError(retcode, process.args,
#     527                                  output=stdout, stderr=stderr)
#     528 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '/srv/conda/envs/notebook/share/pyiron/lammps/bin/run_lammps_2020.03.03.sh' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 6
#       4 job.potential = water_potential
#       5 job.calc_static()
# ----> 6 job.run()
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_base/utils/deprecate.py:171, in Deprecator.__deprecate_argument.<locals>.decorated(*args, **kwargs)
#     161     if kw in self.arguments:
#     162         warnings.warn(
#     163             message_format.format(
#     164                 "{}.{}({}={})".format(
#    (...)
#     169             stacklevel=2,
#     170         )
# --> 171 return function(*args, **kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_base/jobs/job/generic.py:729, in GenericJob.run(self, delete_existing_job, repair, debug, run_mode, run_again)
#     727     self._run_if_repair()
#     728 elif status == "initialized":
# --> 729     self._run_if_new(debug=debug)
#     730 elif status == "created":
#     731     self._run_if_created()
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_base/jobs/job/generic.py:1244, in GenericJob._run_if_new(self, debug)
#    1236 def _run_if_new(self, debug=False):
#    1237     """
#    1238     Internal helper function the run if new function is called when the job status is 'initialized'. It prepares
#    1239     the hdf5 file and the corresponding directory structure.
#    (...)
#    1242         debug (bool): Debug Mode
#    1243     """
# -> 1244     run_job_with_status_initialized(job=self, debug=debug)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_base/jobs/job/runfunction.py:91, in run_job_with_status_initialized(job, debug)
#      89 else:
#      90     job.save()
# ---> 91     job.run()
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_base/utils/deprecate.py:171, in Deprecator.__deprecate_argument.<locals>.decorated(*args, **kwargs)
#     161     if kw in self.arguments:
#     162         warnings.warn(
#     163             message_format.format(
#     164                 "{}.{}({}={})".format(
#    (...)
#     169             stacklevel=2,
#     170         )
# --> 171 return function(*args, **kwargs)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_base/jobs/job/generic.py:731, in GenericJob.run(self, delete_existing_job, repair, debug, run_mode, run_again)
#     729     self._run_if_new(debug=debug)
#     730 elif status == "created":
# --> 731     self._run_if_created()
#     732 elif status == "submitted":
#     733     run_job_with_status_submitted(job=self)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_base/jobs/job/generic.py:1255, in GenericJob._run_if_created(self)
#    1246 def _run_if_created(self):
#    1247     """
#    1248     Internal helper function the run if created function is called when the job status is 'created'. It executes
#    1249     the simulation, either in modal mode, meaning waiting for the simulation to finish, manually, or submits the
#    (...)
#    1253         int: Queue ID - if the job was send to the queue
#    1254     """
# -> 1255     return run_job_with_status_created(job=self)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_base/jobs/job/runfunction.py:114, in run_job_with_status_created(job)
#     112     run_job_with_runmode_manually(job=job, _manually_print=True)
#     113 elif job.server.run_mode.modal:
# --> 114     job.run_static()
#     115 elif job.server.run_mode.srun:
#     116     run_job_with_runmode_srun(job=job)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_base/jobs/job/generic.py:765, in GenericJob.run_static(self)
#     761 def run_static(self):
#     762     """
#     763     The run static function is called by run to execute the simulation.
#     764     """
# --> 765     execute_job_with_external_executable(job=self)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_base/jobs/job/runfunction.py:608, in run_time_decorator.<locals>.wrapper(job)
#     606 if not state.database.database_is_disabled and job.job_id is not None:
#     607     job.project.db.item_update({"timestart": datetime.now()}, job.job_id)
# --> 608     func(job)
#     609     job.project.db.item_update(job._runtime(), job.job_id)
#     610 else:
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_base/jobs/job/runfunction.py:646, in execute_job_with_external_executable(job)
#     636     out = subprocess.run(
#     637         executable,
#     638         cwd=job.project_hdf5.working_directory,
#    (...)
#     643         check=True,
#     644     ).stdout
#     645 except subprocess.CalledProcessError as e:
# --> 646     out, job_crashed = handle_failed_job(job=job, error=e)
#     648 job._logger.info(
#     649     "{}, status: {}, output: {}".format(job.job_info_str, job.status, out)
#     650 )
#     651 with open(
#     652     posixpath.join(job.project_hdf5.working_directory, "error.out"), mode="w"
#     653 ) as f_err:
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_base/jobs/job/runfunction.py:700, in handle_failed_job(job, error)
#     698     if job.server.run_mode.non_modal:
#     699         state.database.close_connection()
# --> 700     raise RuntimeError("Job aborted")
#     701 else:
#     702     return True, out
#
# RuntimeError: Job aborted

# %%
job.executable
# Out:
# '/srv/conda/envs/notebook/share/pyiron/lammps/bin/run_lammps_2020.03.03.sh'

# %%
job

# %%
import subprocess

# %%
job.project_hdf5.working_directory
# Out:
# '/home/jovyan/water_interactive/test_ni_hdf5/test_ni'

# %%
out = subprocess.run(
    str(job.executable),
    cwd=job.project_hdf5.working_directory,
    shell=True,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    universal_newlines=True,
    check=True,
)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 out = subprocess.run(
#       2     str(job.executable),
#       3     cwd=job.project_hdf5.working_directory,
#       4     shell=True,
#       5     stdout=subprocess.PIPE,
#       6     stderr=subprocess.STDOUT,
#       7     universal_newlines=True,
#       8     check=True,
#       9 )
#
# File /srv/conda/envs/notebook/lib/python3.10/subprocess.py:526, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     524     retcode = process.poll()
#     525     if check and retcode:
# --> 526         raise CalledProcessError(retcode, process.args,
#     527                                  output=stdout, stderr=stderr)
#     528 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '/srv/conda/envs/notebook/share/pyiron/lammps/bin/run_lammps_2020.03.03.sh' returned non-zero exit status 1.

# %%
out = subprocess.run(
    str(job.executable),
    cwd=job.project_hdf5.working_directory,
    shell=True,
    stdout=subprocess.PIPE,
    stderr=subprocess.STDOUT,
    universal_newlines=True,
    check=False,
)

# %%
# !cat $str(job.executable)
# Out:
# /bin/bash: line 1: job.executable: command not found
# /bin/bash: line 1: class: No such file or directory

# %%
subprocess.check_output("env", universal_newlines=True, shell=True).split("\n")
# Out:
# ['CPU_GUARANTEE=0.01',
#  'OMPI_MCA_pmix=^s1,s2,cray,isolated',
#  'KUBERNETES_SERVICE_PORT=443',
#  'BINDERHUB_KUBE_STATE_METRICS_PORT_8080_TCP_ADDR=10.99.118.169',
#  'BINDER_SERVICE_PORT=80',
#  'HUB_SERVICE_PORT=8081',
#  'CONDA_PROMPT_MODIFIER=(notebook) ',
#  'BINDER_REF_URL=https://github.com/jan-janssen/debug-pyiron-integration-tests/tree/6839f6d61b2d1af3107ab40a5566c8daaf0ba371',
#  'PROXY_PUBLIC_SERVICE_HOST=10.97.57.57',
#  'HUB_PORT=tcp://10.100.72.226:8081',
#  'BINDER_PORT=tcp://10.103.0.76:80',
#  'BINDERHUB_KUBE_STATE_METRICS_SERVICE_HOST=10.99.118.169',
#  'KUBERNETES_PORT=tcp://10.96.0.1:443',
#  'LANGUAGE=en_US.UTF-8',
#  'BINDERHUB_GRAFANA_PORT_80_TCP_ADDR=10.100.92.6',
#  'PROXY_API_PORT_8001_TCP_PORT=8001',
#  'USER=jovyan',
#  'OMPI_MCA_ess=singleton',
#  'CXXFLAGS=-fvisibility-inlines-hidden -fmessage-length=0 -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /srv/conda/envs/notebook/include',
#  'PROXY_API_PORT_8001_TCP_PROTO=tcp',
#  'JUPYTERHUB_OAUTH_SCOPES=["access:servers!server=jan-janssen-deb-tegration-tests-6l5qyg29/", "access:servers!user=jan-janssen-deb-tegration-tests-6l5qyg29"]',
#  'MPLBACKEND=module://matplotlib_inline.backend_inline',
#  'GCC_RANLIB=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-gcc-ranlib',
#  'HOSTNAME=jupyter-jan-2djanssen-2ddeb-2dtegration-2dtests-2d6l5qyg29',
#  'JUPYTERHUB_HOST=',
#  'OBJCOPY=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-objcopy',
#  'BINDERHUB_KUBE_STATE_METRICS_PORT_8080_TCP_PORT=8080',
#  'PMIX_RANK=0',
#  'BINDERHUB_KUBE_STATE_METRICS_PORT_8080_TCP_PROTO=tcp',
#  'DEBUG_CXXFLAGS=-fvisibility-inlines-hidden -fmessage-length=0 -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-all -fno-plt -Og -g -Wall -Wextra -fvar-tracking-assignments -ffunction-sections -pipe -isystem /srv/conda/envs/notebook/include',
#  'APP_BASE=/srv',
#  'SIZE=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-size',
#  'SHLVL=0',
#  'JUPYTERHUB_USER=jan-janssen-deb-tegration-tests-6l5qyg29',
#  'BINDERHUB_GRAFANA_PORT_80_TCP_PORT=80',
#  'PROXY_API_SERVICE_HOST=10.106.190.169',
#  'HOME=/home/jovyan',
#  'BINDERHUB_GRAFANA_PORT_80_TCP_PROTO=tcp',
#  'BINDERHUB_PROMETHEUS_SERVER_PORT_80_TCP=tcp://10.105.39.0:80',
#  'CC_FOR_BUILD=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-cc',
#  'CONDA_SHLVL=1',
#  'PMIX_NAMESPACE=72679425',
#  'PMIX_DSTORE_21_BASE_PATH=/tmp/ompi.jupyter-jan-2djanssen-2ddeb-2dtegration-2dtests-2d6l5qyg29.1000/pid.678/pmix_dstor_ds21_678',
#  'PMIX_MCA_psec=native',
#  'OMPI_APP_CTX_NUM_PROCS=1',
#  'JUPYTERHUB_SERVICE_URL=http://0.0.0.0:8888/binder/jupyter/user/jan-janssen-deb-tegration-tests-6l5qyg29/',
#  'BINDER_PORT_80_TCP_ADDR=10.103.0.76',
#  'HUB_PORT_8081_TCP=tcp://10.100.72.226:8081',
#  'NPM_DIR=/srv/npm',
#  'HUB_SERVICE_PORT_HUB=8081',
#  'PMIX_GDS_MODULE=ds21,ds12,hash',
#  'PMIX_SYSTEM_TMPDIR=/tmp',
#  'PMIX_MCA_mca_base_component_show_load_errors=1',
#  'PYTHONUNBUFFERED=1',
#  'CONDA_TOOLCHAIN_BUILD=x86_64-conda-linux-gnu',
#  'PROXY_PUBLIC_PORT=tcp://10.97.57.57:443',
#  'JUPYTERHUB_OAUTH_CALLBACK_URL=/binder/jupyter/user/jan-janssen-deb-tegration-tests-6l5qyg29/oauth_callback',
#  'F90=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-gfortran',
#  'JUPYTERHUB_API_URL=http://hub:8081/binder/jupyter/hub/api',
#  'BINDERHUB_KUBE_STATE_METRICS_PORT=tcp://10.99.118.169:8080',
#  'PROXY_PUBLIC_SERVICE_PORT=443',
#  'BINDERHUB_KUBE_STATE_METRICS_SERVICE_PORT=8080',
#  'LDFLAGS=-Wl,-O2 -Wl,--sort-common -Wl,--as-needed -Wl,-z,relro -Wl,-z,now -Wl,--disable-new-dtags -Wl,--gc-sections -Wl,--allow-shlib-undefined -Wl,-rpath,/srv/conda/envs/notebook/lib -Wl,-rpath-link,/srv/conda/envs/notebook/lib -L/srv/conda/envs/notebook/lib',
#  'FC=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-gfortran',
#  'PAGER=cat',
#  'STRINGS=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-strings',
#  'BINDER_PORT_80_TCP_PORT=80',
#  'BINDER_PORT_80_TCP_PROTO=tcp',
#  'PROXY_API_PORT_8001_TCP=tcp://10.106.190.169:8001',
#  '_CE_M=',
#  'CPP=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-cpp',
#  'BINDER_REPO_URL=https://github.com/jan-janssen/debug-pyiron-integration-tests',
#  'PROXY_API_SERVICE_PORT=8001',
#  'JUPYTER_IMAGE=gesiscss/binder-r2d-g5b5b759-jan-2djanssen-2ddebug-2dpyiron-2dintegration-2dtests-684572:6839f6d61b2d1af3107ab40a5566c8daaf0ba371',
#  'F77=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-gfortran',
#  'PROXY_API_PORT=tcp://10.106.190.169:8001',
#  'F95=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-f95',
#  'BINDERHUB_KUBE_STATE_METRICS_PORT_8080_TCP=tcp://10.99.118.169:8080',
#  'BINDERHUB_PROMETHEUS_SERVER_SERVICE_PORT_HTTP=80',
#  'KERNEL_PYTHON_PREFIX=/srv/conda/envs/notebook',
#  'ELFEDIT=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-elfedit',
#  'PROXY_PUBLIC_PORT_80_TCP_ADDR=10.97.57.57',
#  'STRIP=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-strip',
#  'BINDERHUB_GRAFANA_PORT_80_TCP=tcp://10.100.92.6:80',
#  'HFI_NO_BACKTRACE=1',
#  'PMIX_SERVER_URI2=72679424.0;tcp4://127.0.0.1:52387',
#  'PMIX_DSTORE_ESH_BASE_PATH=/tmp/ompi.jupyter-jan-2djanssen-2ddeb-2dtegration-2dtests-2d6l5qyg29.1000/pid.678/pmix_dstor_ds12_678',
#  'PMIX_MCA_gds=ds21,ds12,hash',
#  'GCC=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-gcc',
#  'FORCE_COLOR=1',
#  'PMIX_SERVER_URI3=72679424.0;tcp4://127.0.0.1:52387',
#  'READELF=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-readelf',
#  'JUPYTER_IMAGE_SPEC=gesiscss/binder-r2d-g5b5b759-jan-2djanssen-2ddebug-2dpyiron-2dintegration-2dtests-684572:6839f6d61b2d1af3107ab40a5566c8daaf0ba371',
#  'AR=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-ar',
#  'PROXY_PUBLIC_PORT_80_TCP_PORT=80',
#  'BINDER_PERSISTENT_REQUEST=v2/gh/jan-janssen/debug-pyiron-integration-tests/6839f6d61b2d1af3107ab40a5566c8daaf0ba371',
#  'ORTE_SCHIZO_DETECTION=ORTE',
#  'OMPI_MCA_orte_ess_num_procs=1',
#  'PROXY_PUBLIC_PORT_80_TCP_PROTO=tcp',
#  'GXX=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-g++',
#  'FC_FOR_BUILD=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-gfortran',
#  'AS=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-as',
#  'NPM_CONFIG_GLOBALCONFIG=/srv/npm/npmrc',
#  'JUPYTERHUB_CLIENT_ID=jupyterhub-user-jan-janssen-deb-tegration-tests-6l5qyg29',
#  'TERM=xterm-color',
#  'BINDERHUB_PROMETHEUS_NODE_EXPORTER_PORT_9100_TCP_ADDR=10.110.247.40',
#  'BINDER_PORT_80_TCP=tcp://10.103.0.76:80',
#  '_CE_CONDA=',
#  'KUBERNETES_PORT_443_TCP_ADDR=10.96.0.1',
#  'CXXFILT=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-c++filt',
#  'BINDERHUB_PROMETHEUS_SERVER_SERVICE_HOST=10.105.39.0',
#  'BUILD=x86_64-conda-linux-gnu',
#  'PMIX_VERSION=3.2.5a1',
#  'PATH=/srv/conda/envs/notebook/bin:/srv/conda/condabin:/home/jovyan/.local/bin:/home/jovyan/.local/bin:/srv/conda/envs/notebook/bin:/srv/conda/bin:/srv/npm/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin',
#  'JUPYTERHUB_ACTIVITY_URL=http://hub:8081/binder/jupyter/hub/api/users/jan-janssen-deb-tegration-tests-6l5qyg29/activity',
#  'PMIX_BFROP_BUFFER_TYPE=PMIX_BFROP_BUFFER_NON_DESC',
#  'build_alias=x86_64-conda-linux-gnu',
#  'MEM_LIMIT=4294967296',
#  'BINDERHUB_PROMETHEUS_NODE_EXPORTER_PORT_9100_TCP_PORT=9100',
#  'KUBERNETES_PORT_443_TCP_PORT=443',
#  'CFLAGS=-march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /srv/conda/envs/notebook/include',
#  'PMIX_SECURITY_MODE=native',
#  'MAMBA_ROOT_PREFIX=/srv/conda',
#  'BINDERHUB_PROMETHEUS_NODE_EXPORTER_PORT_9100_TCP_PROTO=tcp',
#  'GCC_AR=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-gcc-ar',
#  'KUBERNETES_PORT_443_TCP_PROTO=tcp',
#  'KMP_INIT_AT_FORK=FALSE',
#  'LANG=en_US.UTF-8',
#  'DEBUG_CFLAGS=-march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-all -fno-plt -Og -g -Wall -Wextra -fvar-tracking-assignments -ffunction-sections -pipe -isystem /srv/conda/envs/notebook/include',
#  'OMPI_MCA_orte_launch=1',
#  'PMIX_SERVER_URI21=72679424.0;tcp4://127.0.0.1:52387',
#  '_CONDA_PYTHON_SYSCONFIGDATA_NAME=_sysconfigdata_x86_64_conda_cos6_linux_gnu',
#  'MESON_ARGS=--buildtype release',
#  'BINDER_LAUNCH_HOST=https://mybinder.org/',
#  'JUPYTERHUB_OAUTH_ACCESS_SCOPES=["access:servers!server=jan-janssen-deb-tegration-tests-6l5qyg29/", "access:servers!user=jan-janssen-deb-tegration-tests-6l5qyg29"]',
#  'BINDERHUB_PROMETHEUS_NODE_EXPORTER_SERVICE_HOST=10.110.247.40',
#  'PMIX_PTL_MODULE=tcp,usock',
#  'PROXY_PUBLIC_PORT_80_TCP=tcp://10.97.57.57:80',
#  'XML_CATALOG_FILES=file:///srv/conda/envs/notebook/etc/xml/catalog file:///etc/xml/catalog',
#  'CPPFLAGS=-DNDEBUG -D_FORTIFY_SOURCE=2 -O2 -isystem /srv/conda/envs/notebook/include',
#  'PROXY_PUBLIC_PORT_443_TCP_ADDR=10.97.57.57',
#  'CONDA_PYTHON_EXE=/srv/conda/bin/python',
#  'DEBIAN_FRONTEND=noninteractive',
#  'OMPI_MCA_orte_precondition_transports=63c4e5305370c74a-5de9a8df9c670920',
#  'SHELL=/bin/bash',
#  'DEBUG_FFLAGS=-march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /srv/conda/envs/notebook/include -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-all -fno-plt -Og -g -Wall -Wextra -fcheck=all -fbacktrace -fimplicit-none -fvar-tracking-assignments -ffunction-sections -pipe',
#  'CMAKE_ARGS=-DCMAKE_AR=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-ar -DCMAKE_CXX_COMPILER_AR=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-gcc-ar -DCMAKE_C_COMPILER_AR=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-gcc-ar -DCMAKE_RANLIB=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-ranlib -DCMAKE_CXX_COMPILER_RANLIB=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-gcc-ranlib -DCMAKE_C_COMPILER_RANLIB=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-gcc-ranlib -DCMAKE_LINKER=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-ld -DCMAKE_STRIP=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-strip -DCMAKE_BUILD_TYPE=Release',
#  'BINDERHUB_PROMETHEUS_SERVER_SERVICE_PORT=80',
#  'HOST=x86_64-conda-linux-gnu',
#  'BINDERHUB_PROMETHEUS_SERVER_PORT=tcp://10.105.39.0:80',
#  'CPU_LIMIT=1.0',
#  'CLICOLOR_FORCE=1',
#  'CXX=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-c++',
#  'DEBUG_CPPFLAGS=-D_DEBUG -D_FORTIFY_SOURCE=2 -Og -isystem /srv/conda/envs/notebook/include',
#  'BINDERHUB_GRAFANA_SERVICE_HOST=10.100.92.6',
#  'REPO_DIR=/home/jovyan',
#  'PROXY_PUBLIC_PORT_443_TCP_PORT=443',
#  'JUPYTERHUB_OAUTH_CLIENT_ALLOWED_SCOPES=[]',
#  'DEBUG_FORTRANFLAGS=-march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /srv/conda/envs/notebook/include -march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-all -fno-plt -Og -g -Wall -Wextra -fcheck=all -fbacktrace -fimplicit-none -fvar-tracking-assignments -ffunction-sections -pipe',
#  'CONDA_DEFAULT_ENV=notebook',
#  'JUPYTERHUB_ADMIN_ACCESS=1',
#  'GPAW_SETUP_PATH=/srv/conda/envs/notebook/share/gpaw',
#  'PROXY_PUBLIC_PORT_443_TCP_PROTO=tcp',
#  'NB_PYTHON_PREFIX=/srv/conda/envs/notebook',
#  'KUBERNETES_SERVICE_PORT_HTTPS=443',
#  'KUBERNETES_PORT_443_TCP=tcp://10.96.0.1:443',
#  'JUPYTERHUB_SERVICE_PREFIX=/binder/jupyter/user/jan-janssen-deb-tegration-tests-6l5qyg29/',
#  'BINDERHUB_PROMETHEUS_NODE_EXPORTER_PORT_9100_TCP=tcp://10.110.247.40:9100',
#  'ADDR2LINE=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-addr2line',
#  'MAMBA_EXE=/srv/conda/bin/mamba',
#  'GCC_NM=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-gcc-nm',
#  'CONDA_PLATFORM=linux-64',
#  'CONDA_DIR=/srv/conda',
#  'GFORTRAN=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-gfortran',
#  'CONDA_BUILD_SYSROOT=/srv/conda/envs/notebook/x86_64-conda-linux-gnu/sysroot',
#  'BINDERHUB_PROMETHEUS_NODE_EXPORTER_SERVICE_PORT=9100',
#  'BINDERHUB_PROMETHEUS_NODE_EXPORTER_PORT=tcp://10.110.247.40:9100',
#  'NB_ENVIRONMENT_FILE=/tmp/env/environment.lock',
#  'GIT_PAGER=cat',
#  'PMIX_SERVER_TMPDIR=/tmp/ompi.jupyter-jan-2djanssen-2ddeb-2dtegration-2dtests-2d6l5qyg29.1000/pid.678',
#  'PMIX_MCA_ptl=tcp,usock',
#  'JUPYTERHUB_API_TOKEN=d8f29183bb144fb5a15b266071206322',
#  'PROXY_PUBLIC_SERVICE_PORT_HTTP=80',
#  'PWD=/home/jovyan',
#  'HUB_SERVICE_HOST=10.100.72.226',
#  'LD_GOLD=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-ld.gold',
#  'BINDER_SERVICE_HOST=10.103.0.76',
#  'KUBERNETES_SERVICE_HOST=10.96.0.1',
#  'LC_ALL=en_US.UTF-8',
#  'BINDERHUB_KUBE_STATE_METRICS_SERVICE_PORT_HTTP=8080',
#  'BINDERHUB_PROMETHEUS_SERVER_PORT_80_TCP_ADDR=10.105.39.0',
#  'CLICOLOR=1',
#  'IPATH_NO_BACKTRACE=1',
#  'BINDER_REQUEST=v2/gh/jan-janssen/debug-pyiron-integration-tests/HEAD',
#  'CONDA_EXE=/srv/conda/bin/conda',
#  'JUPYTERHUB_BASE_URL=/binder/jupyter/',
#  'FFLAGS=-march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /srv/conda/envs/notebook/include',
#  'MEM_GUARANTEE=471859200',
#  'JUPYTERHUB_SERVER_NAME=',
#  'LD=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-ld',
#  'HUB_PORT_8081_TCP_ADDR=10.100.72.226',
#  'JPY_PARENT_PID=493',
#  'BINDERHUB_GRAFANA_SERVICE_PORT_SERVICE=80',
#  'BINDERHUB_GRAFANA_SERVICE_PORT=80',
#  'BINDERHUB_GRAFANA_PORT=tcp://10.100.92.6:80',
#  'PYDEVD_USE_FRAME_EVAL=NO',
#  'GPROF=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-gprof',
#  'BINDERHUB_PROMETHEUS_SERVER_PORT_80_TCP_PORT=80',
#  'CONDA_PREFIX=/srv/conda/envs/notebook',
#  'CONDA_TOOLCHAIN_HOST=x86_64-conda-linux-gnu',
#  'JPY_API_TOKEN=d8f29183bb144fb5a15b266071206322',
#  'host_alias=x86_64-conda-linux-gnu',
#  'FORTRANFLAGS=-march=nocona -mtune=haswell -ftree-vectorize -fPIC -fstack-protector-strong -fno-plt -O2 -ffunction-sections -pipe -isystem /srv/conda/envs/notebook/include',
#  'CC=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-cc',
#  'RANLIB=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-ranlib',
#  'JPY_SESSION_NAME=d6df0e0b-25b4-4f80-a760-4ee32cb8954e',
#  'CXX_FOR_BUILD=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-c++',
#  'BINDERHUB_PROMETHEUS_SERVER_PORT_80_TCP_PROTO=tcp',
#  'HUB_PORT_8081_TCP_PORT=8081',
#  'PROXY_API_PORT_8001_TCP_ADDR=10.106.190.169',
#  'CMAKE_PREFIX_PATH=/srv/conda/envs/notebook:/srv/conda/envs/notebook/x86_64-conda-linux-gnu/sysroot/usr',
#  'BINDERHUB_PROMETHEUS_NODE_EXPORTER_SERVICE_PORT_METRICS=9100',
#  'PROXY_PUBLIC_PORT_443_TCP=tcp://10.97.57.57:443',
#  'PROXY_PUBLIC_SERVICE_PORT_HTTPS=443',
#  'NM=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-nm',
#  'OBJDUMP=/srv/conda/envs/notebook/bin/x86_64-conda-linux-gnu-objdump',
#  'HUB_PORT_8081_TCP_PROTO=tcp',
#  'PMIX_HOSTNAME=jupyter-jan-2djanssen-2ddeb-2dtegration-2dtests-2d6l5qyg29',
#  '']

# %%
subprocess.check_output("bash " + str(job.executable), cwd=job.project_hdf5.working_directory, shell=True)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 subprocess.check_output("bash " + str(job.executable), cwd=job.project_hdf5.working_directory, shell=True)
#
# File /srv/conda/envs/notebook/lib/python3.10/subprocess.py:421, in check_output(timeout, *popenargs, **kwargs)
#     418         empty = b''
#     419     kwargs['input'] = empty
# --> 421 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     422            **kwargs).stdout
#
# File /srv/conda/envs/notebook/lib/python3.10/subprocess.py:526, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     524     retcode = process.poll()
#     525     if check and retcode:
# --> 526         raise CalledProcessError(retcode, process.args,
#     527                                  output=stdout, stderr=stderr)
#     528 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command 'bash /srv/conda/envs/notebook/share/pyiron/lammps/bin/run_lammps_2020.03.03.sh' returned non-zero exit status 1.

# %%
out
# Out:
# CompletedProcess(args='/srv/conda/envs/notebook/share/pyiron/lammps/bin/run_lammps_2020.03.03.sh', returncode=1, stdout='')

# %%
job.run_static()
# Out:
# 2024-01-12 11:12:04,570 - pyiron_log - WARNING - Job aborted
# 2024-01-12 11:12:04,572 - pyiron_log - WARNING -
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_base/jobs/job/runfunction.py:636, in execute_job_with_external_executable(job)
#     635 try:
# --> 636     out = subprocess.run(
#     637         executable,
#     638         cwd=job.project_hdf5.working_directory,
#     639         shell=shell,
#     640         stdout=subprocess.PIPE,
#     641         stderr=subprocess.STDOUT,
#     642         universal_newlines=True,
#     643         check=True,
#     644     ).stdout
#     645 except subprocess.CalledProcessError as e:
#
# File /srv/conda/envs/notebook/lib/python3.10/subprocess.py:526, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     525     if check and retcode:
# --> 526         raise CalledProcessError(retcode, process.args,
#     527                                  output=stdout, stderr=stderr)
#     528 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '/srv/conda/envs/notebook/share/pyiron/lammps/bin/run_lammps_2020.03.03.sh' returned non-zero exit status 1.
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 job.run_static()
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_base/jobs/job/generic.py:765, in GenericJob.run_static(self)
#     761 def run_static(self):
#     762     """
#     763     The run static function is called by run to execute the simulation.
#     764     """
# --> 765     execute_job_with_external_executable(job=self)
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_base/jobs/job/runfunction.py:608, in run_time_decorator.<locals>.wrapper(job)
#     606 if not state.database.database_is_disabled and job.job_id is not None:
#     607     job.project.db.item_update({"timestart": datetime.now()}, job.job_id)
# --> 608     func(job)
#     609     job.project.db.item_update(job._runtime(), job.job_id)
#     610 else:
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_base/jobs/job/runfunction.py:646, in execute_job_with_external_executable(job)
#     636     out = subprocess.run(
#     637         executable,
#     638         cwd=job.project_hdf5.working_directory,
#    (...)
#     643         check=True,
#     644     ).stdout
#     645 except subprocess.CalledProcessError as e:
# --> 646     out, job_crashed = handle_failed_job(job=job, error=e)
#     648 job._logger.info(
#     649     "{}, status: {}, output: {}".format(job.job_info_str, job.status, out)
#     650 )
#     651 with open(
#     652     posixpath.join(job.project_hdf5.working_directory, "error.out"), mode="w"
#     653 ) as f_err:
#
# File /srv/conda/envs/notebook/lib/python3.10/site-packages/pyiron_base/jobs/job/runfunction.py:700, in handle_failed_job(job, error)
#     698     if job.server.run_mode.non_modal:
#     699         state.database.close_connection()
# --> 700     raise RuntimeError("Job aborted")
#     701 else:
#     702     return True, out
#
# RuntimeError: Job aborted

# %%
job["error.msg"]
# Out:
# []

# %%
# Assert that the unit converstions work even in the interactive mode

int_nodes = job_int["output/generic"].list_nodes()
usual_nodes = job["output/generic"].list_nodes()
for node in int_nodes:
    if node in usual_nodes:
        print(node)
        assert np.allclose(job_int["output/generic/" + node], job["output/generic/" + node])
